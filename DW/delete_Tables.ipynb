# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
# List Of Tables
tables = [
    "dim_date",
    "dim_device",
    "dim_game",
    "dim_location",
    "dim_payment",
    "dim_trophy",
    "dim_user",
    "fact_game_stats",
    "fact_orders",
    "fact_trophies"
]

# Drop Tables
for table in tables:
    spark.sql(f"DROP TABLE IF EXISTS Gaming_Platform_DW.dbo.{table}")
    print(f"Deleted: {table}")
# Out:
# StatementMeta(, 2c2c434c-e255-4dba-8295-c75ccfb45c85, 3, Finished, Available, Finished, False)
# Deleted: dim_date
# Deleted: dim_device
# Deleted: dim_game
# Deleted: dim_location
# Deleted: dim_payment
# Deleted: dim_trophy
# Deleted: dim_user
# Deleted: fact_game_stats
# Deleted: fact_orders
# Deleted: fact_trophies
