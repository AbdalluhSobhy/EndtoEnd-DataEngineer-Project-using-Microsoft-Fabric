# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
# Truncate all Gaming_Platform_DW tables
tables = [
    "fact_game_stats",
    "fact_orders", 
    "fact_trophies",
    "dim_device",
    "dim_game",
    "dim_location",
    "dim_payment",
    "dim_trophy",
    "dim_user",
]

for table in tables:
    spark.sql(f"TRUNCATE TABLE {table}")
    print(f"Truncated: {table}")
# Out:
# StatementMeta(, 75161df1-e3c6-4a93-9db7-2fcea050678f, 3, Finished, Available, Finished, False)
# Truncated: fact_game_stats
# Truncated: fact_orders
# Truncated: fact_trophies
# Truncated: dim_device
# Truncated: dim_game
# Truncated: dim_location
# Truncated: dim_payment
# Truncated: dim_trophy
# Truncated: dim_user

# %%
spark.sql(f"TRUNCATE TABLE trophies ")
# Out:
# StatementMeta(, a195f4ca-6459-4f35-93f4-bad932832f7d, -1, Cancelled, , Cancelled, True)

# %%
df = spark.sql("SELECT * FROM GamingPlatform_STG.dbo.trophies LIMIT 1000")
display(df)
# Out:
# StatementMeta(, a195f4ca-6459-4f35-93f4-bad932832f7d, 4, Finished, Available, Finished, True)
# SynapseWidget(Synapse.DataFrame, 0e313075-09cc-4873-a64f-a24f07f9aec6)
